# %% [markdown]
# 6. Running SQL Queries

# %%
#Query 1: Average Spending per Transaction in Each Category

from tabulate import tabulate

query1 = """
SELECT category, ROUND(AVG(amount), 2) AS avg_spent
FROM expenses_data
GROUP BY category
ORDER BY avg_spent DESC;
"""
cursor.execute(query1)
result1 = cursor.fetchall()

headers = ["Category", "Average Spent"]
print(tabulate(result1, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+-----------------+
# | Category        |   Average Spent |
# +=================+=================+
# | Shopping        |          710.65 |
# +-----------------+-----------------+
# | Medical Expense |          709.44 |
# +-----------------+-----------------+
# | Groceries       |          697.57 |
# +-----------------+-----------------+
# | Transportation  |          691.46 |
# +-----------------+-----------------+
# | Subscription    |          690.54 |
# +-----------------+-----------------+
# | EMI             |          690.26 |
# +-----------------+-----------------+
# | Insurance       |          684.32 |
# +-----------------+-----------------+
# | Electronics     |          683.99 |
# +-----------------+-----------------+
# | Bills           |          682.21 |
# +-----------------+-----------------+

# %%
#Query 2: Most Frequently Used Payment Mode

query2 = """
SELECT payment_mode, COUNT(*) AS count
FROM expenses_data
GROUP BY payment_mode
ORDER BY count DESC
LIMIT 1;
"""
cursor.execute(query2)
result2 = cursor.fetchall()

headers = ["Payment Mode", "Usage Count"]
print(tabulate(result2, headers=headers, tablefmt="grid"))
# Out:
# +----------------+---------------+
# | Payment Mode   |   Usage Count |
# +================+===============+
# | Debit card     |          6355 |
# +----------------+---------------+

# %%
#Query 3: Top 10 Highest Transactions by Amount
query3 = """
SELECT date, category, description, payment_mode, amount
FROM expenses_data
ORDER BY amount DESC
LIMIT 10;
"""
cursor.execute(query3)
result3 = cursor.fetchall()

headers = ["Date", "Category", "Description", "Payment Mode", "Amount"]
print(tabulate(result3, headers=headers, tablefmt="grid"))
# Out:
# +------------+-----------------+------------------+----------------+----------+
# | Date       | Category        | Description      | Payment Mode   |   Amount |
# +============+=================+==================+================+==========+
# | 2024-08-11 | Bills           | Electricity bill | Cash           |  1999.81 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-07-02 | Subscription    | Netflix          | UPI            |  1999.8  |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-07-02 | Subscription    | Netflix          | UPI            |  1999.8  |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-07-21 | Groceries       | Grains & Bread   | UPI            |  1999.48 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-01-01 | Medical Expense | Consultation Fee | Credit card    |  1999.33 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-02-21 | Groceries       | Diary & eggs     | Debit card     |  1999.12 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-01-30 | Transportation  | Bus              | Debit card     |  1998.39 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-03-03 | Shopping        | Shopping expense | UPI            |  1998.23 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-03-03 | Shopping        | Shopping expense | UPI            |  1998.23 |
# +------------+-----------------+------------------+----------------+----------+
# | 2024-10-24 | EMI             | Mobile           | Debit card     |  1998.1  |
# +------------+-----------------+------------------+----------------+----------+

# %%
#Query 4: Top 5 Categories by Number of Transactions
query4 = """
SELECT category, COUNT(*) AS transaction_count
FROM expenses_data
GROUP BY category
ORDER BY transaction_count DESC
LIMIT 5;
"""
cursor.execute(query4)
result4 = cursor.fetchall()

headers = ["Category", "Transaction Count"]
print(tabulate(result4, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+---------------------+
# | Category        |   Transaction Count |
# +=================+=====================+
# | Subscription    |                2880 |
# +-----------------+---------------------+
# | Shopping        |                2866 |
# +-----------------+---------------------+
# | Medical Expense |                2854 |
# +-----------------+---------------------+
# | Transportation  |                2813 |
# +-----------------+---------------------+
# | Insurance       |                2789 |
# +-----------------+---------------------+

# %%
#Query 5: Average Monthly Spending

query5 = """
SELECT strftime('%m', date) AS month, ROUND(AVG(amount), 2) AS avg_monthly_spent
FROM expenses_data
GROUP BY month
ORDER BY month;
"""
cursor.execute(query5)
result5 = cursor.fetchall()

headers = ["Month", "Average Monthly Spent"]
print(tabulate(result5, headers=headers, tablefmt="grid"))
# Out:
# +---------+-------------------------+
# |   Month |   Average Monthly Spent |
# +=========+=========================+
# |      01 |                  708.49 |
# +---------+-------------------------+
# |      02 |                  724.11 |
# +---------+-------------------------+
# |      03 |                  721.3  |
# +---------+-------------------------+
# |      04 |                  694.81 |
# +---------+-------------------------+
# |      05 |                  700.98 |
# +---------+-------------------------+
# |      06 |                  688.15 |
# +---------+-------------------------+
# |      07 |                  708.3  |
# +---------+-------------------------+
# |      08 |                  687.07 |
# +---------+-------------------------+
# |      09 |                  704.59 |
# +---------+-------------------------+
# |      10 |                  687.68 |
# +---------+-------------------------+
# |      11 |                  697.06 |
# +---------+-------------------------+
# |      12 |                  690.49 |
# +---------+-------------------------+

# %%
#Query 6: Categories with Most Cashback Earned

query6 = """
SELECT category, SUM(cashback) AS total_cashback
FROM expenses_data
GROUP BY category
ORDER BY total_cashback DESC;
"""
cursor.execute(query6)
result6 = cursor.fetchall()

headers = ["Category", "Total Cashback"]
print(tabulate(result6, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+------------------+
# | Category        |   Total Cashback |
# +=================+==================+
# | Subscription    |          8157.18 |
# +-----------------+------------------+
# | Electronics     |          7776.12 |
# +-----------------+------------------+
# | Medical Expense |          7594.52 |
# +-----------------+------------------+
# | EMI             |          7511.36 |
# +-----------------+------------------+
# | Insurance       |          7335.46 |
# +-----------------+------------------+
# | Shopping        |          7204.3  |
# +-----------------+------------------+
# | Bills           |          7153.09 |
# +-----------------+------------------+
# | Groceries       |          7060.61 |
# +-----------------+------------------+
# | Transportation  |          6890.33 |
# +-----------------+------------------+

# %%
#Query 7: Total Spend Per Description
query7 = """
SELECT description, SUM(amount) AS total
FROM expenses_data
GROUP BY description
ORDER BY total DESC;
"""
cursor.execute(query7)
result7 = cursor.fetchall()

headers = ["Description", "Total Spent"]
print(tabulate(result7, headers=headers, tablefmt="grid"))
# Out:
# +------------------+------------------+
# | Description      |      Total Spent |
# +==================+==================+
# | Shopping expense |      2.05769e+06 |
# +------------------+------------------+
# | Mobile           |      1.15375e+06 |
# +------------------+------------------+
# | Medicine         |      1.02843e+06 |
# +------------------+------------------+
# | Consultation Fee |      1.01889e+06 |
# +------------------+------------------+
# | Auto insurance   | 664877           |
# +------------------+------------------+
# | Laptop           | 656748           |
# +------------------+------------------+
# | Life insurance   | 644631           |
# +------------------+------------------+
# | Health insurance | 624925           |
# +------------------+------------------+
# | Tablet           | 618626           |
# +------------------+------------------+
# | Netflix          | 517216           |
# +------------------+------------------+
# | Zomato           | 513426           |
# +------------------+------------------+
# | Train            | 505532           |
# +------------------+------------------+
# | Amazon Prime     | 497172           |
# +------------------+------------------+
# | Ola              | 488008           |
# +------------------+------------------+
# | Flight           | 486489           |
# +------------------+------------------+
# | Bus              | 486002           |
# +------------------+------------------+
# | Air conditioner  | 482015           |
# +------------------+------------------+
# | Spotify          | 481885           |
# +------------------+------------------+
# | Car              | 480366           |
# +------------------+------------------+
# | Washing machine  | 465430           |
# +------------------+------------------+
# | Mobile Recharge  | 393330           |
# +------------------+------------------+
# | Wifi bill        | 391955           |
# +------------------+------------------+
# | Gas bill         | 386987           |
# +------------------+------------------+
# | Water bill       | 375344           |
# +------------------+------------------+
# | Beverages        | 355778           |
# +------------------+------------------+
# | Electricity bill | 353695           |
# +------------------+------------------+
# | Grains & Bread   | 352888           |
# +------------------+------------------+
# | Diary & eggs     | 314670           |
# +------------------+------------------+
# | Fruits           | 298344           |
# +------------------+------------------+
# | Vegetables       | 298202           |
# +------------------+------------------+
# | Spices           | 274058           |
# +------------------+------------------+

# %%
#Query 8: Cashback as a Percentage of Total Spend by Category

query8 = """
SELECT category,
       ROUND(SUM(cashback) * 100.0 / SUM(amount), 2) AS cashback_percentage
FROM expenses_data
GROUP BY category
ORDER BY cashback_percentage DESC;
"""
cursor.execute(query8)
result8 = cursor.fetchall()

headers = ["Category", "Cashback % of Total Spend"]
print(tabulate(result8, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+-----------------------------+
# | Category        |   Cashback % of Total Spend |
# +=================+=============================+
# | Subscription    |                        0.41 |
# +-----------------+-----------------------------+
# | Electronics     |                        0.4  |
# +-----------------+-----------------------------+
# | EMI             |                        0.39 |
# +-----------------+-----------------------------+
# | Insurance       |                        0.38 |
# +-----------------+-----------------------------+
# | Bills           |                        0.38 |
# +-----------------+-----------------------------+
# | Medical Expense |                        0.37 |
# +-----------------+-----------------------------+
# | Groceries       |                        0.37 |
# +-----------------+-----------------------------+
# | Transportation  |                        0.35 |
# +-----------------+-----------------------------+
# | Shopping        |                        0.35 |
# +-----------------+-----------------------------+

# %%
#Query 9: Transactions Where Cashback > 25% of Amount Paid


query9 = """
SELECT date, category, description, amount, cashback
FROM expenses_data
WHERE cashback > (amount * 0.25);
"""
cursor.execute(query9)
result9 = cursor.fetchall()

headers = ["Date", "Category", "Description", "Amount Paid", "Cashback"]
print(tabulate(result9, headers=headers, tablefmt="grid"))
# Out:
# +------------+-----------------+------------------+---------------+------------+
# | Date       | Category        | Description      |   Amount Paid |   Cashback |
# +============+=================+==================+===============+============+
# | 2024-08-09 | Insurance       | Auto insurance   |         66.55 |      18.67 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-08-09 | Insurance       | Auto insurance   |         66.55 |      18.67 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-10-15 | Subscription    | Netflix          |         64.81 |      17.44 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-10-15 | Subscription    | Netflix          |         64.81 |      17.44 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-04-21 | Shopping        | Shopping expense |         59.53 |      16.4  |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-09-01 | EMI             | Mobile           |         76.93 |      19.54 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-09-06 | EMI             | Car              |         51.29 |      17.44 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-03-22 | Subscription    | Amazon Prime     |         62.76 |      17.37 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-04-09 | Subscription    | Netflix          |         50.49 |      15.38 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-01-19 | Transportation  | Bus              |         52.71 |      13.32 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-05-16 | EMI             | Air conditioner  |         53.94 |      17.83 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-08-23 | Electronics     | Tablet           |         59.33 |      18.82 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-10-07 | Groceries       | Diary & eggs     |         54.44 |      14.69 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-10-25 | Shopping        | Shopping expense |         52.64 |      14.48 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-12-04 | Groceries       | Diary & eggs     |         54.59 |      14.6  |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-02-05 | Electronics     | Mobile           |         56.19 |      14.22 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-07-29 | Electronics     | Mobile           |         69.69 |      18.46 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-10-22 | Transportation  | Bus              |         61.71 |      16    |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-01-05 | Subscription    | Spotify          |         62.46 |      18.16 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-04-08 | Subscription    | Zomato           |         71.77 |      18.91 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-03-21 | Bills           | Wifi bill        |         57.16 |      16.29 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-04-02 | Subscription    | Zomato           |         66.09 |      18.64 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-04-06 | Electronics     | Mobile           |         53.69 |      15.64 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-05-03 | Shopping        | Shopping expense |         55.29 |      19.7  |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-11-01 | EMI             | Air conditioner  |         59.49 |      16.23 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-03-22 | Groceries       | Spices           |         56.76 |      15.13 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-05-13 | Electronics     | Laptop           |         68.7  |      18.69 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-09-29 | EMI             | Air conditioner  |         63.89 |      17.48 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-02-13 | Insurance       | Health insurance |         58.03 |      15.56 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-12-18 | Electronics     | Mobile           |         51.99 |      16.82 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-01-03 | Medical Expense | Medicine         |         57.97 |      18.36 |
# +------------+-----------------+------------------+---------------+------------+
# | 2024-02-08 | Transportation  | Train            |         53.97 |      15.04 |
# +------------+-----------------+------------------+---------------+------------+

# %%
#Query 10: Highest Spending Day

query10 = """
SELECT date, SUM(amount) AS total_spent
FROM expenses_data
GROUP BY date
ORDER BY total_spent DESC
LIMIT 1;
"""
cursor.execute(query10)
result10 = cursor.fetchall()

headers = ["Date", "Total Spent"]
print(tabulate(result10, headers=headers, tablefmt="grid"))
# Out:
# +------------+---------------+
# | Date       |   Total Spent |
# +============+===============+
# | 2024-09-24 |       76519.8 |
# +------------+---------------+

# %%
#Query 11: Day with Maximum Number of Transactions

query11 = """
SELECT date, COUNT(*) AS transaction_count
FROM expenses_data
GROUP BY date
ORDER BY transaction_count DESC
LIMIT 1;
"""
cursor.execute(query11)
result11 = cursor.fetchall()

headers = ["Date", "Transaction Count"]
print(tabulate(result11, headers=headers, tablefmt="grid"))
# Out:
# +------------+---------------------+
# | Date       |   Transaction Count |
# +============+=====================+
# | 2024-01-17 |                  96 |
# +------------+---------------------+

# %%
#Query 12: Number of Unique Descriptions per Category

query12 = """
SELECT category, COUNT(DISTINCT description) AS unique_descriptions
FROM expenses_data
GROUP BY category
ORDER BY unique_descriptions DESC;
"""
cursor.execute(query12)
result12 = cursor.fetchall()

headers = ["Category", "Unique Descriptions"]
print(tabulate(result12, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+-----------------------+
# | Category        |   Unique Descriptions |
# +=================+=======================+
# | Groceries       |                     6 |
# +-----------------+-----------------------+
# | Bills           |                     5 |
# +-----------------+-----------------------+
# | Transportation  |                     4 |
# +-----------------+-----------------------+
# | Subscription    |                     4 |
# +-----------------+-----------------------+
# | EMI             |                     4 |
# +-----------------+-----------------------+
# | Insurance       |                     3 |
# +-----------------+-----------------------+
# | Electronics     |                     3 |
# +-----------------+-----------------------+
# | Medical Expense |                     2 |
# +-----------------+-----------------------+
# | Shopping        |                     1 |
# +-----------------+-----------------------+

# %%
#Query 13: Spending Breakdown - different payment modes per Month

query13 = """
SELECT strftime('%m', date) AS month,
       payment_mode,
       SUM(amount) AS total
FROM expenses_data
GROUP BY month, payment_mode
ORDER BY month;
"""
cursor.execute(query13)
result13 = cursor.fetchall()

headers = ["Month", "Payment Mode", "Total Spent"]
print(tabulate(result13, headers=headers, tablefmt="grid"))
# Out:
# +---------+----------------+---------------+
# |   Month | Payment Mode   |   Total Spent |
# +=========+================+===============+
# |      01 | Cash           |        358675 |
# +---------+----------------+---------------+
# |      01 | Credit card    |        372845 |
# +---------+----------------+---------------+
# |      01 | Debit card     |        373998 |
# +---------+----------------+---------------+
# |      01 | UPI            |        382311 |
# +---------+----------------+---------------+
# |      02 | Cash           |        390937 |
# +---------+----------------+---------------+
# |      02 | Credit card    |        411688 |
# +---------+----------------+---------------+
# |      02 | Debit card     |        345819 |
# +---------+----------------+---------------+
# |      02 | UPI            |        372184 |
# +---------+----------------+---------------+
# |      03 | Cash           |        358142 |
# +---------+----------------+---------------+
# |      03 | Credit card    |        384919 |
# +---------+----------------+---------------+
# |      03 | Debit card     |        392314 |
# +---------+----------------+---------------+
# |      03 | UPI            |        379352 |
# +---------+----------------+---------------+
# |      04 | Cash           |        376606 |
# +---------+----------------+---------------+
# |      04 | Credit card    |        400487 |
# +---------+----------------+---------------+
# |      04 | Debit card     |        323283 |
# +---------+----------------+---------------+
# |      04 | UPI            |        358721 |
# +---------+----------------+---------------+
# |      05 | Cash           |        341451 |
# +---------+----------------+---------------+
# |      05 | Credit card    |        359987 |
# +---------+----------------+---------------+
# |      05 | Debit card     |        400069 |
# +---------+----------------+---------------+
# |      05 | UPI            |        370543 |
# +---------+----------------+---------------+
# |      06 | Cash           |        369615 |
# +---------+----------------+---------------+
# |      06 | Credit card    |        366952 |
# +---------+----------------+---------------+
# |      06 | Debit card     |        367492 |
# +---------+----------------+---------------+
# |      06 | UPI            |        341062 |
# +---------+----------------+---------------+
# |      07 | Cash           |        372700 |
# +---------+----------------+---------------+
# |      07 | Credit card    |        342584 |
# +---------+----------------+---------------+
# |      07 | Debit card     |        360222 |
# +---------+----------------+---------------+
# |      07 | UPI            |        411929 |
# +---------+----------------+---------------+
# |      08 | Cash           |        392394 |
# +---------+----------------+---------------+
# |      08 | Credit card    |        354745 |
# +---------+----------------+---------------+
# |      08 | Debit card     |        346667 |
# +---------+----------------+---------------+
# |      08 | UPI            |        349034 |
# +---------+----------------+---------------+
# |      09 | Cash           |        382257 |
# +---------+----------------+---------------+
# |      09 | Credit card    |        340336 |
# +---------+----------------+---------------+
# |      09 | Debit card     |        417490 |
# +---------+----------------+---------------+
# |      09 | UPI            |        339565 |
# +---------+----------------+---------------+
# |      10 | Cash           |        336145 |
# +---------+----------------+---------------+
# |      10 | Credit card    |        367384 |
# +---------+----------------+---------------+
# |      10 | Debit card     |        380083 |
# +---------+----------------+---------------+
# |      10 | UPI            |        360519 |
# +---------+----------------+---------------+
# |      11 | Cash           |        393970 |
# +---------+----------------+---------------+
# |      11 | Credit card    |        392445 |
# +---------+----------------+---------------+
# |      11 | Debit card     |        362351 |
# +---------+----------------+---------------+
# |      11 | UPI            |        315056 |
# +---------+----------------+---------------+
# |      12 | Cash           |        357729 |
# +---------+----------------+---------------+
# |      12 | Credit card    |        373198 |
# +---------+----------------+---------------+
# |      12 | Debit card     |        359046 |
# +---------+----------------+---------------+
# |      12 | UPI            |        360058 |
# +---------+----------------+---------------+

# %%
# Query 14: Count of Transactions where amount spent is greater than 1800

query14 = """
SELECT COUNT(*) AS transactions_over_1800
FROM expenses_data
WHERE amount > 1800;
"""
cursor.execute(query14)
result14 = cursor.fetchall()

headers = ["Transactions > 1800"]
print(tabulate(result14, headers=headers, tablefmt="grid"))
# Out:
# +-----------------------+
# |   Transactions > 1800 |
# +=======================+
# |                   950 |
# +-----------------------+

# %%
#Query 15: Min and Max Spend Per Category

query15 = """
SELECT category, MIN(amount) AS min_spent, MAX(amount) AS max_spent
FROM expenses_data
GROUP BY category
ORDER BY category;
"""
cursor.execute(query15)
result15 = cursor.fetchall()

headers = ["Category", "Min Spent", "Max Spent"]
print(tabulate(result15, headers=headers, tablefmt="grid"))
# Out:
# +-----------------+-------------+-------------+
# | Category        |   Min Spent |   Max Spent |
# +=================+=============+=============+
# | Bills           |       50.11 |     1999.81 |
# +-----------------+-------------+-------------+
# | EMI             |       50.07 |     1998.1  |
# +-----------------+-------------+-------------+
# | Electronics     |       51.34 |     1997.29 |
# +-----------------+-------------+-------------+
# | Groceries       |       50.22 |     1999.48 |
# +-----------------+-------------+-------------+
# | Insurance       |       50.41 |     1995.74 |
# +-----------------+-------------+-------------+
# | Medical Expense |       50.01 |     1999.33 |
# +-----------------+-------------+-------------+
# | Shopping        |       50.15 |     1998.23 |
# +-----------------+-------------+-------------+
# | Subscription    |       50.39 |     1999.8  |
# +-----------------+-------------+-------------+
# | Transportation  |       50.28 |     1998.39 |
# +-----------------+-------------+-------------+

# %%
#Query 16: Transactions Where Description is 'Netflix'

query16 = """
SELECT date, category, payment_mode, description, amount, cashback
FROM expenses_data
WHERE LOWER(description) = 'netflix';
"""
cursor.execute(query16)
result16 = cursor.fetchall()

headers = ["Date", "Category", "Payment Mode", "Description", "Amount", "Cashback"]
print(tabulate(result16, headers=headers, tablefmt="grid"))
# Out:
# +------------+--------------+----------------+---------------+----------+------------+
# | Date       | Category     | Payment Mode   | Description   |   Amount |   Cashback |
# +============+==============+================+===============+==========+============+
# | 2024-01-02 | Subscription | Debit card     | Netflix       |  1486.21 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-14 | Subscription | Cash           | Netflix       |   794.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-01 | Subscription | UPI            | Netflix       |  1987.47 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-13 | Subscription | Cash           | Netflix       |  1853.91 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-15 | Subscription | Debit card     | Netflix       |   938.69 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-18 | Subscription | Debit card     | Netflix       |   335.78 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-19 | Subscription | Cash           | Netflix       |  1370.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-06 | Subscription | Debit card     | Netflix       |   496.39 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-22 | Subscription | Credit card    | Netflix       |  1061.47 |       6.56 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-08 | Subscription | Credit card    | Netflix       |   977.18 |      10.13 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-29 | Subscription | Credit card    | Netflix       |  1771.63 |       6.38 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-02 | Subscription | Cash           | Netflix       |  1359.18 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-04 | Subscription | UPI            | Netflix       |   158.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-10 | Subscription | Debit card     | Netflix       |  1880.65 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-11 | Subscription | Credit card    | Netflix       |  1405.22 |       9.66 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-16 | Subscription | UPI            | Netflix       |  1100.35 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-08 | Subscription | Cash           | Netflix       |   595.3  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-02 | Subscription | UPI            | Netflix       |  1999.8  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-04 | Subscription | Credit card    | Netflix       |  1858.77 |      16.1  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-18 | Subscription | UPI            | Netflix       |   690.97 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-19 | Subscription | Credit card    | Netflix       |   353    |      13.03 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-02 | Subscription | Credit card    | Netflix       |   391.24 |      11.48 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-09 | Subscription | Debit card     | Netflix       |   507.11 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-28 | Subscription | Credit card    | Netflix       |  1222.72 |      14.75 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-13 | Subscription | Debit card     | Netflix       |   974.03 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-22 | Subscription | Debit card     | Netflix       |   117.24 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-04 | Subscription | Credit card    | Netflix       |   381.03 |      17.55 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-12 | Subscription | Cash           | Netflix       |  1568.81 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-17 | Subscription | Debit card     | Netflix       |  1301.25 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-30 | Subscription | UPI            | Netflix       |   586.95 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-02 | Subscription | Debit card     | Netflix       |  1486.21 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-14 | Subscription | Cash           | Netflix       |   794.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-01 | Subscription | UPI            | Netflix       |  1987.47 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-13 | Subscription | Cash           | Netflix       |  1853.91 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-15 | Subscription | Debit card     | Netflix       |   938.69 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-18 | Subscription | Debit card     | Netflix       |   335.78 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-19 | Subscription | Cash           | Netflix       |  1370.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-06 | Subscription | Debit card     | Netflix       |   496.39 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-22 | Subscription | Credit card    | Netflix       |  1061.47 |       6.56 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-08 | Subscription | Credit card    | Netflix       |   977.18 |      10.13 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-29 | Subscription | Credit card    | Netflix       |  1771.63 |       6.38 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-02 | Subscription | Cash           | Netflix       |  1359.18 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-04 | Subscription | UPI            | Netflix       |   158.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-10 | Subscription | Debit card     | Netflix       |  1880.65 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-11 | Subscription | Credit card    | Netflix       |  1405.22 |       9.66 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-16 | Subscription | UPI            | Netflix       |  1100.35 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-08 | Subscription | Cash           | Netflix       |   595.3  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-02 | Subscription | UPI            | Netflix       |  1999.8  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-04 | Subscription | Credit card    | Netflix       |  1858.77 |      16.1  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-18 | Subscription | UPI            | Netflix       |   690.97 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-19 | Subscription | Credit card    | Netflix       |   353    |      13.03 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-02 | Subscription | Credit card    | Netflix       |   391.24 |      11.48 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-09 | Subscription | Debit card     | Netflix       |   507.11 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-28 | Subscription | Credit card    | Netflix       |  1222.72 |      14.75 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-13 | Subscription | Debit card     | Netflix       |   974.03 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-22 | Subscription | Debit card     | Netflix       |   117.24 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-04 | Subscription | Credit card    | Netflix       |   381.03 |      17.55 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-12 | Subscription | Cash           | Netflix       |  1568.81 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-17 | Subscription | Debit card     | Netflix       |  1301.25 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-30 | Subscription | UPI            | Netflix       |   586.95 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-09 | Subscription | Cash           | Netflix       |  1207.18 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-18 | Subscription | UPI            | Netflix       |   119.91 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-15 | Subscription | Debit card     | Netflix       |  1245.38 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-27 | Subscription | Credit card    | Netflix       |  1510.13 |      17.15 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-28 | Subscription | Credit card    | Netflix       |  1326    |      18.71 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-08 | Subscription | Cash           | Netflix       |  1100.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-12 | Subscription | Credit card    | Netflix       |  1897.69 |       2.78 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-13 | Subscription | UPI            | Netflix       |   125.61 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-16 | Subscription | Credit card    | Netflix       |   121.24 |      18.34 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-21 | Subscription | UPI            | Netflix       |  1477.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-22 | Subscription | Debit card     | Netflix       |  1546.03 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-02 | Subscription | Debit card     | Netflix       |   241.01 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-04 | Subscription | Credit card    | Netflix       |   945.71 |      18.49 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-16 | Subscription | Credit card    | Netflix       |  1190.08 |      19.49 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-17 | Subscription | Credit card    | Netflix       |   895.73 |       3.49 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-24 | Subscription | Cash           | Netflix       |  1731.77 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-04 | Subscription | UPI            | Netflix       |   974.75 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-15 | Subscription | UPI            | Netflix       |  1213.95 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-28 | Subscription | UPI            | Netflix       |   427.87 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-11 | Subscription | UPI            | Netflix       |  1774.04 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-17 | Subscription | Cash           | Netflix       |  1052.74 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-19 | Subscription | Debit card     | Netflix       |  1801.19 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-21 | Subscription | Credit card    | Netflix       |  1620.69 |       4.18 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-11 | Subscription | Debit card     | Netflix       |   337.18 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-08 | Subscription | UPI            | Netflix       |   854.92 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-26 | Subscription | UPI            | Netflix       |  1339.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-29 | Subscription | Credit card    | Netflix       |   655.17 |       3.98 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-22 | Subscription | Credit card    | Netflix       |   261.87 |       6.77 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-22 | Subscription | UPI            | Netflix       |  1104.05 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-26 | Subscription | Debit card     | Netflix       |  1221.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-26 | Subscription | Debit card     | Netflix       |  1686.3  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-03 | Subscription | Credit card    | Netflix       |    59.8  |       8.73 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-04 | Subscription | UPI            | Netflix       |  1791.11 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-10 | Subscription | UPI            | Netflix       |  1128.45 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-01 | Subscription | Credit card    | Netflix       |  1978.21 |      14.3  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-14 | Subscription | Cash           | Netflix       |  1333.81 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-17 | Subscription | Cash           | Netflix       |  1830.37 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-18 | Subscription | Credit card    | Netflix       |   441.35 |       8.97 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-18 | Subscription | Credit card    | Netflix       |   471.53 |       4.5  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-17 | Subscription | Credit card    | Netflix       |   332.59 |      12.63 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-21 | Subscription | Cash           | Netflix       |  1013.26 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-05 | Subscription | UPI            | Netflix       |  1348.02 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-08 | Subscription | UPI            | Netflix       |   379.45 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-29 | Subscription | UPI            | Netflix       |  1258.46 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-04 | Subscription | UPI            | Netflix       |  1958.88 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-28 | Subscription | Debit card     | Netflix       |   356.76 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-17 | Subscription | Debit card     | Netflix       |   238.59 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-29 | Subscription | UPI            | Netflix       |  1167.2  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-03 | Subscription | UPI            | Netflix       |  1017.4  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-07 | Subscription | UPI            | Netflix       |  1398.29 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-09 | Subscription | UPI            | Netflix       |  1886.33 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-21 | Subscription | Credit card    | Netflix       |  1436.82 |       4.43 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-15 | Subscription | UPI            | Netflix       |  1860.47 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-04 | Subscription | UPI            | Netflix       |  1515.45 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-17 | Subscription | Cash           | Netflix       |   233.26 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-18 | Subscription | Credit card    | Netflix       |   443.87 |      15.44 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-19 | Subscription | Cash           | Netflix       |  1650.72 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-19 | Subscription | UPI            | Netflix       |   765.79 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-04 | Subscription | Credit card    | Netflix       |   305.26 |       4.95 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-04 | Subscription | Credit card    | Netflix       |   421.33 |      13.4  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-09 | Subscription | Credit card    | Netflix       |  1458.67 |       9.76 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-25 | Subscription | Cash           | Netflix       |  1411.62 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-03 | Subscription | Cash           | Netflix       |  1789.66 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-08 | Subscription | Cash           | Netflix       |    73.37 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-22 | Subscription | Credit card    | Netflix       |  1624.52 |      12.21 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-29 | Subscription | Cash           | Netflix       |  1231.77 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-12 | Subscription | Credit card    | Netflix       |  1824.68 |      12.75 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-21 | Subscription | UPI            | Netflix       |   686.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-30 | Subscription | UPI            | Netflix       |  1014.49 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-15 | Subscription | UPI            | Netflix       |   463.09 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-22 | Subscription | Credit card    | Netflix       |  1357.54 |       9.59 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-04 | Subscription | Debit card     | Netflix       |  1760.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-04 | Subscription | UPI            | Netflix       |  1746.83 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-05 | Subscription | UPI            | Netflix       |  1834.66 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-11 | Subscription | Credit card    | Netflix       |  1397.77 |      15.2  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-10 | Subscription | Debit card     | Netflix       |   371.8  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-06 | Subscription | Cash           | Netflix       |   415.14 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-13 | Subscription | Credit card    | Netflix       |  1991.21 |       7.33 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-13 | Subscription | Cash           | Netflix       |  1686.85 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-14 | Subscription | Credit card    | Netflix       |  1288.11 |       4.66 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-24 | Subscription | Credit card    | Netflix       |   679.56 |       9.22 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-03 | Subscription | Credit card    | Netflix       |    98.23 |      19.3  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-08 | Subscription | Credit card    | Netflix       |  1062.14 |       8.46 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-21 | Subscription | Cash           | Netflix       |  1948.12 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-14 | Subscription | Credit card    | Netflix       |  1383.44 |      17.03 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-15 | Subscription | Credit card    | Netflix       |  1637.92 |      16.6  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-26 | Subscription | UPI            | Netflix       |  1289.07 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-28 | Subscription | Debit card     | Netflix       |  1080.07 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-06 | Subscription | Cash           | Netflix       |  1711.48 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-06 | Subscription | Credit card    | Netflix       |  1480.18 |      12.69 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-14 | Subscription | UPI            | Netflix       |   275.31 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-17 | Subscription | Credit card    | Netflix       |  1591.24 |      19.6  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-20 | Subscription | UPI            | Netflix       |   733.46 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-01 | Subscription | Debit card     | Netflix       |   718.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-18 | Subscription | Debit card     | Netflix       |  1567.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-05 | Subscription | Cash           | Netflix       |   247.84 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-23 | Subscription | Cash           | Netflix       |  1178.09 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-27 | Subscription | Debit card     | Netflix       |  1002.57 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-11 | Subscription | Debit card     | Netflix       |   874.94 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-15 | Subscription | Credit card    | Netflix       |    64.81 |      17.44 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-28 | Subscription | UPI            | Netflix       |   699.77 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-29 | Subscription | Debit card     | Netflix       |   495    |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-03 | Subscription | Cash           | Netflix       |  1734.01 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-04 | Subscription | Cash           | Netflix       |   976.43 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-10 | Subscription | Credit card    | Netflix       |   386.26 |      16.15 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-12 | Subscription | Debit card     | Netflix       |  1615.72 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-17 | Subscription | Credit card    | Netflix       |   416.68 |       5.13 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-20 | Subscription | UPI            | Netflix       |   257.98 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-28 | Subscription | UPI            | Netflix       |   346.5  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-28 | Subscription | UPI            | Netflix       |   924.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-03 | Subscription | Credit card    | Netflix       |  1750.2  |       9.21 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-04 | Subscription | UPI            | Netflix       |   600.96 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-13 | Subscription | Debit card     | Netflix       |  1874.82 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-15 | Subscription | UPI            | Netflix       |   463.09 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-22 | Subscription | Credit card    | Netflix       |  1357.54 |       9.59 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-04 | Subscription | Debit card     | Netflix       |  1760.9  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-04 | Subscription | UPI            | Netflix       |  1746.83 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-05 | Subscription | UPI            | Netflix       |  1834.66 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-11 | Subscription | Credit card    | Netflix       |  1397.77 |      15.2  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-10 | Subscription | Debit card     | Netflix       |   371.8  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-06 | Subscription | Cash           | Netflix       |   415.14 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-13 | Subscription | Credit card    | Netflix       |  1991.21 |       7.33 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-13 | Subscription | Cash           | Netflix       |  1686.85 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-14 | Subscription | Credit card    | Netflix       |  1288.11 |       4.66 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-24 | Subscription | Credit card    | Netflix       |   679.56 |       9.22 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-03 | Subscription | Credit card    | Netflix       |    98.23 |      19.3  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-08 | Subscription | Credit card    | Netflix       |  1062.14 |       8.46 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-21 | Subscription | Cash           | Netflix       |  1948.12 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-14 | Subscription | Credit card    | Netflix       |  1383.44 |      17.03 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-15 | Subscription | Credit card    | Netflix       |  1637.92 |      16.6  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-26 | Subscription | UPI            | Netflix       |  1289.07 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-28 | Subscription | Debit card     | Netflix       |  1080.07 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-06 | Subscription | Cash           | Netflix       |  1711.48 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-06 | Subscription | Credit card    | Netflix       |  1480.18 |      12.69 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-14 | Subscription | UPI            | Netflix       |   275.31 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-17 | Subscription | Credit card    | Netflix       |  1591.24 |      19.6  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-20 | Subscription | UPI            | Netflix       |   733.46 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-01 | Subscription | Debit card     | Netflix       |   718.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-18 | Subscription | Debit card     | Netflix       |  1567.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-05 | Subscription | Cash           | Netflix       |   247.84 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-23 | Subscription | Cash           | Netflix       |  1178.09 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-27 | Subscription | Debit card     | Netflix       |  1002.57 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-11 | Subscription | Debit card     | Netflix       |   874.94 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-15 | Subscription | Credit card    | Netflix       |    64.81 |      17.44 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-28 | Subscription | UPI            | Netflix       |   699.77 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-29 | Subscription | Debit card     | Netflix       |   495    |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-03 | Subscription | Cash           | Netflix       |  1734.01 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-04 | Subscription | Cash           | Netflix       |   976.43 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-10 | Subscription | Credit card    | Netflix       |   386.26 |      16.15 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-12 | Subscription | Debit card     | Netflix       |  1615.72 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-17 | Subscription | Credit card    | Netflix       |   416.68 |       5.13 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-20 | Subscription | UPI            | Netflix       |   257.98 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-28 | Subscription | UPI            | Netflix       |   346.5  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-28 | Subscription | UPI            | Netflix       |   924.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-03 | Subscription | Credit card    | Netflix       |  1750.2  |       9.21 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-04 | Subscription | UPI            | Netflix       |   600.96 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-13 | Subscription | Debit card     | Netflix       |  1874.82 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-30 | Subscription | Credit card    | Netflix       |  1263.15 |       2.25 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-20 | Subscription | Debit card     | Netflix       |  1430.47 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-06 | Subscription | Debit card     | Netflix       |   771.44 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-06 | Subscription | UPI            | Netflix       |  1952.51 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-08 | Subscription | UPI            | Netflix       |  1714.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-22 | Subscription | Credit card    | Netflix       |  1148.97 |       9.28 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-23 | Subscription | Debit card     | Netflix       |   871.71 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-23 | Subscription | Cash           | Netflix       |  1558.47 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-26 | Subscription | UPI            | Netflix       |   433.77 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-29 | Subscription | Credit card    | Netflix       |  1861.94 |      19.81 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-12 | Subscription | UPI            | Netflix       |   531.59 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-17 | Subscription | UPI            | Netflix       |  1555.81 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-26 | Subscription | Credit card    | Netflix       |  1616.47 |       3.69 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-04 | Subscription | UPI            | Netflix       |  1259.72 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-08 | Subscription | Debit card     | Netflix       |   489.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-10 | Subscription | Cash           | Netflix       |   848.76 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-12 | Subscription | Debit card     | Netflix       |   726.24 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-22 | Subscription | Cash           | Netflix       |   133.24 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-30 | Subscription | Debit card     | Netflix       |   629.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-13 | Subscription | Credit card    | Netflix       |    67.03 |       7.71 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-22 | Subscription | Cash           | Netflix       |   476.34 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-02 | Subscription | Cash           | Netflix       |   889.64 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-02 | Subscription | Cash           | Netflix       |   582.59 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-19 | Subscription | Cash           | Netflix       |  1708.2  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-25 | Subscription | Cash           | Netflix       |  1993.83 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-26 | Subscription | Debit card     | Netflix       |  1010.1  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-06 | Subscription | UPI            | Netflix       |  1654.85 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-06 | Subscription | UPI            | Netflix       |   441.13 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-13 | Subscription | UPI            | Netflix       |   154.87 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-17 | Subscription | UPI            | Netflix       |  1411.24 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-30 | Subscription | Cash           | Netflix       |  1279.12 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-01 | Subscription | Debit card     | Netflix       |   655.3  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-13 | Subscription | Cash           | Netflix       |  1054.53 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-13 | Subscription | Credit card    | Netflix       |   908.65 |      12.71 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-20 | Subscription | UPI            | Netflix       |  1148.71 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-11 | Subscription | UPI            | Netflix       |  1136.1  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-13 | Subscription | Credit card    | Netflix       |  1523.22 |       3.51 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-14 | Subscription | Cash           | Netflix       |   599.57 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-17 | Subscription | Cash           | Netflix       |   343.89 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-18 | Subscription | Cash           | Netflix       |  1686.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-15 | Subscription | Debit card     | Netflix       |   270.19 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-17 | Subscription | Cash           | Netflix       |   334.27 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-04 | Subscription | UPI            | Netflix       |  1359.68 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-15 | Subscription | Credit card    | Netflix       |   967.79 |       7.59 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-24 | Subscription | Cash           | Netflix       |  1389.15 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-27 | Subscription | Debit card     | Netflix       |   246.81 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-27 | Subscription | Debit card     | Netflix       |   429.36 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-12 | Subscription | Debit card     | Netflix       |   371.64 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-26 | Subscription | Cash           | Netflix       |   788.54 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-11 | Subscription | Cash           | Netflix       |  1763.49 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-15 | Subscription | Credit card    | Netflix       |  1929.58 |       5.12 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-04 | Subscription | Cash           | Netflix       |  1209.16 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-21 | Subscription | Debit card     | Netflix       |   903.08 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-26 | Subscription | Cash           | Netflix       |   682.52 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-27 | Subscription | UPI            | Netflix       |  1749.79 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-29 | Subscription | UPI            | Netflix       |  1609.88 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-29 | Subscription | Debit card     | Netflix       |   254.46 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# ...
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-29 | Subscription | Credit card    | Netflix       |   669.66 |      13.09 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-11 | Subscription | UPI            | Netflix       |   166.15 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-28 | Subscription | UPI            | Netflix       |   601.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-02 | Subscription | Cash           | Netflix       |    69.78 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-18 | Subscription | Cash           | Netflix       |   144.31 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-19 | Subscription | Credit card    | Netflix       |    62.31 |       9.31 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-23 | Subscription | Debit card     | Netflix       |   869.01 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-26 | Subscription | Debit card     | Netflix       |   386.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-04 | Subscription | Debit card     | Netflix       |   499.19 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-20 | Subscription | UPI            | Netflix       |   451.65 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-08 | Subscription | Cash           | Netflix       |   304.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-13 | Subscription | Cash           | Netflix       |   310.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-12 | Subscription | Credit card    | Netflix       |   596.73 |       9.25 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-01 | Subscription | Debit card     | Netflix       |   650.23 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-16 | Subscription | Debit card     | Netflix       |   358    |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-29 | Subscription | Credit card    | Netflix       |   158.94 |      16.6  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-04 | Subscription | Credit card    | Netflix       |   175.15 |       9.33 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-03 | Subscription | Cash           | Netflix       |   430.36 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-08 | Subscription | UPI            | Netflix       |   950.12 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-01-28 | Subscription | Credit card    | Netflix       |   121.49 |       1.37 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-06 | Subscription | Debit card     | Netflix       |   562.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-07 | Subscription | Credit card    | Netflix       |   287.1  |       7.11 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-11 | Subscription | Credit card    | Netflix       |   282.71 |       2.88 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-22 | Subscription | UPI            | Netflix       |   624.7  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-03 | Subscription | Cash           | Netflix       |   118.02 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-19 | Subscription | Cash           | Netflix       |   618.87 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-26 | Subscription | Cash           | Netflix       |   397.03 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-07 | Subscription | Credit card    | Netflix       |   800.07 |      15.2  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-14 | Subscription | Cash           | Netflix       |   680.26 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-18 | Subscription | Cash           | Netflix       |   706.46 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-20 | Subscription | Credit card    | Netflix       |   333.31 |       3.09 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-24 | Subscription | Debit card     | Netflix       |   976.58 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-27 | Subscription | UPI            | Netflix       |   234.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-19 | Subscription | Cash           | Netflix       |   589.82 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-28 | Subscription | Debit card     | Netflix       |   261.14 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-30 | Subscription | Cash           | Netflix       |   383.56 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-07 | Subscription | Credit card    | Netflix       |   429.03 |       6.3  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-10 | Subscription | Credit card    | Netflix       |   381.6  |      10.87 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-08 | Subscription | Debit card     | Netflix       |   399.52 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-26 | Subscription | Debit card     | Netflix       |   459.37 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-29 | Subscription | Credit card    | Netflix       |   485.07 |       7.83 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-05 | Subscription | Cash           | Netflix       |   907.04 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-15 | Subscription | Cash           | Netflix       |   802.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-15 | Subscription | Debit card     | Netflix       |   335.95 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-17 | Subscription | Cash           | Netflix       |   559.59 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-06 | Subscription | Cash           | Netflix       |   141.66 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-20 | Subscription | UPI            | Netflix       |   237.21 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-29 | Subscription | Cash           | Netflix       |   753.66 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-05 | Subscription | UPI            | Netflix       |   191.73 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-15 | Subscription | Credit card    | Netflix       |   368.14 |       7.56 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-19 | Subscription | Credit card    | Netflix       |   937.09 |      13.8  |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-09 | Subscription | UPI            | Netflix       |   645.85 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-12 | Subscription | UPI            | Netflix       |   179.11 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-20 | Subscription | Cash           | Netflix       |   121.22 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-02 | Subscription | Debit card     | Netflix       |   775.18 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-03 | Subscription | Cash           | Netflix       |   822.31 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-12 | Subscription | Credit card    | Netflix       |   711.07 |      10.22 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-28 | Subscription | UPI            | Netflix       |   245.52 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-28 | Subscription | UPI            | Netflix       |   982.15 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-28 | Subscription | Cash           | Netflix       |   749.2  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-03 | Subscription | Credit card    | Netflix       |   307.13 |       5.87 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-05 | Subscription | Cash           | Netflix       |   593    |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-02-21 | Subscription | UPI            | Netflix       |   134.92 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-11 | Subscription | Cash           | Netflix       |   870.85 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-03-29 | Subscription | Debit card     | Netflix       |   617.2  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-01 | Subscription | UPI            | Netflix       |   192.32 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-15 | Subscription | Debit card     | Netflix       |   966.64 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-20 | Subscription | Cash           | Netflix       |   542.25 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-22 | Subscription | UPI            | Netflix       |   158.6  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-04-24 | Subscription | Debit card     | Netflix       |   535.64 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-01 | Subscription | Cash           | Netflix       |   362.67 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-14 | Subscription | UPI            | Netflix       |   413.1  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-05-25 | Subscription | Cash           | Netflix       |   914.8  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-08 | Subscription | Credit card    | Netflix       |   404.71 |      17.13 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-06-15 | Subscription | UPI            | Netflix       |   238.63 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-21 | Subscription | Cash           | Netflix       |   159.09 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-22 | Subscription | Cash           | Netflix       |   611.2  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-07-26 | Subscription | Debit card     | Netflix       |   241.91 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-09 | Subscription | Credit card    | Netflix       |   536.01 |      18.37 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-09 | Subscription | Credit card    | Netflix       |   775.42 |      11.55 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-08-26 | Subscription | Debit card     | Netflix       |   262.55 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-01 | Subscription | Credit card    | Netflix       |   341.46 |       8.79 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-04 | Subscription | Credit card    | Netflix       |   607.13 |      18.35 |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-10 | Subscription | Cash           | Netflix       |   536.49 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-09-27 | Subscription | Debit card     | Netflix       |   852.71 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-01 | Subscription | UPI            | Netflix       |   697.38 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-03 | Subscription | Debit card     | Netflix       |   872.1  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-20 | Subscription | Cash           | Netflix       |   395.53 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-10-27 | Subscription | Debit card     | Netflix       |   487.1  |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-11-20 | Subscription | UPI            | Netflix       |   907.32 |       0    |
# +------------+--------------+----------------+---------------+----------+------------+
# | 2024-12-02 | Subscription | Credit card    | Netflix       |   688.84 |      10.19 |
# +------------+--------------+----------------+---------------+----------+------------+

# %%
#Query 17: Transactions Where Cashback is Between 1 and 4

query17 = """
SELECT date, category, payment_mode, description, amount, cashback
FROM expenses_data
WHERE cashback BETWEEN 1 AND 4;
"""
cursor.execute(query17)
result17 = cursor.fetchall()

headers = ["Date", "Category", "Payment Mode", "Description", "Amount", "Cashback"]
print(tabulate(result17, headers=headers, tablefmt="grid"))
# Out:
# +------------+-----------------+----------------+------------------+----------+------------+
# | Date       | Category        | Payment Mode   | Description      |   Amount |   Cashback |
# +============+=================+================+==================+==========+============+
# | 2024-01-04 | Subscription    | Credit card    | Zomato           |  1962.28 |       1.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-11 | Shopping        | Credit card    | Shopping expense |   992.71 |       2.47 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-12 | Electronics     | Credit card    | Laptop           |  1106.77 |       2.22 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-12 | Transportation  | Credit card    | Ola              |  1303.47 |       3.95 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-16 | Bills           | Credit card    | Electricity bill |  1390.9  |       2.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-25 | Shopping        | Credit card    | Shopping expense |  1431.15 |       1.77 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-25 | EMI             | Credit card    | Air conditioner  |  1277.68 |       3.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-28 | Groceries       | Credit card    | Vegetables       |  1042.76 |       1.29 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-07 | Transportation  | Credit card    | Bus              |  1596.59 |       3    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-20 | Transportation  | Credit card    | Train            |   794.41 |       3.66 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-03 | Shopping        | Credit card    | Shopping expense |   753.03 |       2.12 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-07 | Transportation  | Credit card    | Ola              |  1819.45 |       2.26 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-09 | Subscription    | Credit card    | Zomato           |   927.54 |       3.63 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-13 | Electronics     | Credit card    | Mobile           |   945.95 |       1.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-10 | Medical Expense | Credit card    | Consultation Fee |   927.62 |       1.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-02 | Electronics     | Credit card    | Laptop           |  1664.55 |       2.27 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-09 | Shopping        | Credit card    | Shopping expense |  1452.12 |       1.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-15 | Medical Expense | Credit card    | Consultation Fee |  1467.76 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Electronics     | Credit card    | Tablet           |  1192.61 |       2.97 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-01 | Transportation  | Credit card    | Bus              |  1184.47 |       1.64 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-10 | Shopping        | Credit card    | Shopping expense |  1633.97 |       3.77 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-12 | Electronics     | Credit card    | Mobile           |  1666.57 |       1.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-14 | Subscription    | Credit card    | Amazon Prime     |   325.48 |       2.28 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-16 | Shopping        | Credit card    | Shopping expense |   746.83 |       1.2  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | Groceries       | Credit card    | Spices           |  1274.68 |       1.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-04 | Medical Expense | Credit card    | Medicine         |   938.1  |       1.75 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-12 | Medical Expense | Credit card    | Medicine         |  1418.03 |       2.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-14 | Shopping        | Credit card    | Shopping expense |  1231.88 |       3.79 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-26 | Groceries       | Credit card    | Diary & eggs     |   769.8  |       1.76 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-11 | Shopping        | Credit card    | Shopping expense |  1380.99 |       3.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-27 | Bills           | Credit card    | Gas bill         |   760.75 |       2.41 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-07 | Insurance       | Credit card    | Auto insurance   |   710.28 |       2.38 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-08 | Bills           | Credit card    | Water bill       |  1376.95 |       3.69 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-16 | Groceries       | Credit card    | Diary & eggs     |   233.11 |       1.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-23 | Insurance       | Credit card    | Life insurance   |  1554.5  |       3.18 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-28 | Shopping        | Credit card    | Shopping expense |   833.54 |       2.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-04 | Subscription    | Credit card    | Zomato           |  1962.28 |       1.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-11 | Shopping        | Credit card    | Shopping expense |   992.71 |       2.47 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-12 | Electronics     | Credit card    | Laptop           |  1106.77 |       2.22 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-12 | Transportation  | Credit card    | Ola              |  1303.47 |       3.95 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-16 | Bills           | Credit card    | Electricity bill |  1390.9  |       2.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-25 | Shopping        | Credit card    | Shopping expense |  1431.15 |       1.77 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-25 | EMI             | Credit card    | Air conditioner  |  1277.68 |       3.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-28 | Groceries       | Credit card    | Vegetables       |  1042.76 |       1.29 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-07 | Transportation  | Credit card    | Bus              |  1596.59 |       3    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-20 | Transportation  | Credit card    | Train            |   794.41 |       3.66 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-03 | Shopping        | Credit card    | Shopping expense |   753.03 |       2.12 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-07 | Transportation  | Credit card    | Ola              |  1819.45 |       2.26 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-09 | Subscription    | Credit card    | Zomato           |   927.54 |       3.63 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-13 | Electronics     | Credit card    | Mobile           |   945.95 |       1.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-10 | Medical Expense | Credit card    | Consultation Fee |   927.62 |       1.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-02 | Electronics     | Credit card    | Laptop           |  1664.55 |       2.27 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-09 | Shopping        | Credit card    | Shopping expense |  1452.12 |       1.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-15 | Medical Expense | Credit card    | Consultation Fee |  1467.76 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Electronics     | Credit card    | Tablet           |  1192.61 |       2.97 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-01 | Transportation  | Credit card    | Bus              |  1184.47 |       1.64 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-10 | Shopping        | Credit card    | Shopping expense |  1633.97 |       3.77 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-12 | Electronics     | Credit card    | Mobile           |  1666.57 |       1.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-14 | Subscription    | Credit card    | Amazon Prime     |   325.48 |       2.28 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-16 | Shopping        | Credit card    | Shopping expense |   746.83 |       1.2  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | Groceries       | Credit card    | Spices           |  1274.68 |       1.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-04 | Medical Expense | Credit card    | Medicine         |   938.1  |       1.75 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-12 | Medical Expense | Credit card    | Medicine         |  1418.03 |       2.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-14 | Shopping        | Credit card    | Shopping expense |  1231.88 |       3.79 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-26 | Groceries       | Credit card    | Diary & eggs     |   769.8  |       1.76 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-11 | Shopping        | Credit card    | Shopping expense |  1380.99 |       3.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-27 | Bills           | Credit card    | Gas bill         |   760.75 |       2.41 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-07 | Insurance       | Credit card    | Auto insurance   |   710.28 |       2.38 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-08 | Bills           | Credit card    | Water bill       |  1376.95 |       3.69 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-16 | Groceries       | Credit card    | Diary & eggs     |   233.11 |       1.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-23 | Insurance       | Credit card    | Life insurance   |  1554.5  |       3.18 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-28 | Shopping        | Credit card    | Shopping expense |   833.54 |       2.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-14 | Insurance       | Credit card    | Health insurance |   452.03 |       1.74 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-15 | Subscription    | Credit card    | Spotify          |   506.62 |       2.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-06 | EMI             | Credit card    | Mobile           |   542.25 |       1.39 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-12 | Bills           | Credit card    | Electricity bill |   646.96 |       2.56 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-15 | Shopping        | Credit card    | Shopping expense |  1571.04 |       3.96 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-20 | Transportation  | Credit card    | Train            |  1631.08 |       2    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-27 | Bills           | Credit card    | Mobile Recharge  |  1935.88 |       2.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-03 | Bills           | Credit card    | Mobile Recharge  |   883.79 |       3.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-05 | Groceries       | Credit card    | Spices           |   472.05 |       3.23 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-06 | Groceries       | Credit card    | Spices           |  1413.25 |       1.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-08 | Medical Expense | Credit card    | Medicine         |  1756.11 |       1.07 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-08 | Electronics     | Credit card    | Laptop           |   690.59 |       1.71 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-13 | EMI             | Credit card    | Washing machine  |   536.61 |       1.56 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-17 | Medical Expense | Credit card    | Medicine         |   934.27 |       2.57 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-25 | EMI             | Credit card    | Car              |  1637.9  |       2.4  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-27 | Bills           | Credit card    | Wifi bill        |  1165.55 |       1.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-06 | Transportation  | Credit card    | Ola              |   946.72 |       1.68 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-06 | Insurance       | Credit card    | Health insurance |  1234.93 |       2.89 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-12 | Subscription    | Credit card    | Netflix          |  1897.69 |       2.78 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-14 | EMI             | Credit card    | Mobile           |   124.06 |       1.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-18 | Insurance       | Credit card    | Life insurance   |  1089.81 |       2.66 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-01 | Bills           | Credit card    | Electricity bill |  1437.79 |       1.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-07 | Medical Expense | Credit card    | Medicine         |  1637.05 |       1.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-13 | Shopping        | Credit card    | Shopping expense |  1353.31 |       3.6  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-17 | Subscription    | Credit card    | Netflix          |   895.73 |       3.49 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-22 | Insurance       | Credit card    | Life insurance   |  1523.82 |       1.62 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-25 | Bills           | Credit card    | Water bill       |   313.68 |       1.1  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-29 | EMI             | Credit card    | Mobile           |  1615.23 |       3.48 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-01 | Medical Expense | Credit card    | Medicine         |   953.8  |       3    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-22 | Groceries       | Credit card    | Spices           |   835.02 |       1.43 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-22 | Bills           | Credit card    | Water bill       |   974.49 |       2.08 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-27 | Groceries       | Credit card    | Spices           |  1134.34 |       3.05 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-19 | Electronics     | Credit card    | Tablet           |   334.04 |       2.56 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Medical Expense | Credit card    | Medicine         |  1580.93 |       1.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Electronics     | Credit card    | Mobile           |  1925.33 |       3.39 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-01 | Groceries       | Credit card    | Grains & Bread   |  1394.26 |       1.38 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-02 | Transportation  | Credit card    | Train            |   499.58 |       2.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-06 | Bills           | Credit card    | Water bill       |   895.95 |       1.35 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-07 | Electronics     | Credit card    | Laptop           |   868.31 |       3.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-07 | EMI             | Credit card    | Washing machine  |   973.39 |       2.28 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-08 | Medical Expense | Credit card    | Consultation Fee |   552.49 |       3.48 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-08 | Shopping        | Credit card    | Shopping expense |  1249.64 |       1.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-17 | Insurance       | Credit card    | Auto insurance   |   526.94 |       2.05 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-29 | Shopping        | Credit card    | Shopping expense |  1540.32 |       2.46 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-05 | Shopping        | Credit card    | Shopping expense |   838.24 |       3.65 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-10 | Insurance       | Credit card    | Health insurance |  1839.51 |       1.65 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-24 | Shopping        | Credit card    | Shopping expense |   727.36 |       3.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-29 | Subscription    | Credit card    | Netflix          |   655.17 |       3.98 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-12 | Groceries       | Credit card    | Beverages        |  1416.97 |       3.59 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-19 | Medical Expense | Credit card    | Consultation Fee |   511.97 |       1.75 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-25 | Medical Expense | Credit card    | Consultation Fee |  1530.42 |       2.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-01 | Medical Expense | Credit card    | Consultation Fee |  1999.33 |       2.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-07 | EMI             | Credit card    | Car              |   875.75 |       2.02 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-07 | Medical Expense | Credit card    | Consultation Fee |  1484.84 |       2.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-13 | Subscription    | Credit card    | Amazon Prime     |  1772.62 |       2.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-14 | Bills           | Credit card    | Electricity bill |   617.31 |       2.84 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-19 | Bills           | Credit card    | Gas bill         |  1443.85 |       2.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-24 | Medical Expense | Credit card    | Consultation Fee |  1314.01 |       1.14 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-28 | Transportation  | Credit card    | Train            |   547.12 |       2.33 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-03 | Bills           | Credit card    | Wifi bill        |  1330.36 |       1.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-08 | EMI             | Credit card    | Air conditioner  |   498.88 |       1.57 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-15 | Insurance       | Credit card    | Life insurance   |  1318.63 |       2.71 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-17 | Bills           | Credit card    | Water bill       |   719.77 |       2.91 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-09 | Groceries       | Credit card    | Grains & Bread   |   465.77 |       1.07 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-13 | Transportation  | Credit card    | Flight           |  1477.56 |       1.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-02 | Bills           | Credit card    | Water bill       |   759.48 |       1.63 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-17 | Electronics     | Credit card    | Mobile           |  1851.81 |       3.09 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-22 | Medical Expense | Credit card    | Consultation Fee |  1107.6  |       2.51 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-28 | Medical Expense | Credit card    | Consultation Fee |   245.98 |       1.39 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-21 | Insurance       | Credit card    | Life insurance   |  1054.9  |       2.95 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-04 | Medical Expense | Credit card    | Consultation Fee |   295.48 |       3.92 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-14 | Bills           | Credit card    | Electricity bill |    83.97 |       2.76 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Groceries       | Credit card    | Spices           |   184.27 |       1.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-26 | Transportation  | Credit card    | Bus              |  1940.02 |       1.41 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-04 | Groceries       | Credit card    | Vegetables       |  1597.44 |       2.87 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-11 | Shopping        | Credit card    | Shopping expense |  1411.33 |       2.44 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-13 | Insurance       | Credit card    | Auto insurance   |   585.8  |       3.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-28 | Medical Expense | Credit card    | Consultation Fee |   407.89 |       2.51 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-04 | Shopping        | Credit card    | Shopping expense |   549.27 |       2.99 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-04 | Transportation  | Credit card    | Train            |   350.4  |       2.15 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-18 | Bills           | Credit card    | Mobile Recharge  |  1750.89 |       1.61 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-22 | Transportation  | Credit card    | Bus              |  1987.56 |       1.05 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-09 | Transportation  | Credit card    | Ola              |  1546.92 |       2.19 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-22 | Groceries       | Credit card    | Grains & Bread   |   992.06 |       3    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-09 | Transportation  | Credit card    | Bus              |   880.07 |       2    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-14 | Electronics     | Credit card    | Laptop           |  1501.83 |       1.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-15 | Transportation  | Credit card    | Ola              |   109.17 |       2.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-22 | Groceries       | Credit card    | Fruits           |  1982.64 |       2.1  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-27 | Groceries       | Credit card    | Beverages        |   616.43 |       2.89 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-01 | Transportation  | Credit card    | Ola              |   709.45 |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-19 | EMI             | Credit card    | Mobile           |  1966.53 |       3.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-21 | Bills           | Credit card    | Gas bill         |   716.96 |       3.42 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-02 | EMI             | Credit card    | Washing machine  |   680.37 |       3.34 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-07 | Bills           | Credit card    | Wifi bill        |  1231.15 |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-12 | Bills           | Credit card    | Mobile Recharge  |   976.4  |       3.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-22 | Electronics     | Credit card    | Tablet           |  1880.6  |       3.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-24 | Transportation  | Credit card    | Bus              |  1075.64 |       3.23 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-25 | Subscription    | Credit card    | Spotify          |  1280.86 |       1.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-04 | Transportation  | Credit card    | Ola              |  1182.05 |       3.61 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-07 | Shopping        | Credit card    | Shopping expense |  1206.14 |       1.96 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-11 | Bills           | Credit card    | Wifi bill        |   180.41 |       1.51 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-19 | Insurance       | Credit card    | Auto insurance   |  1254.81 |       3.12 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-22 | Insurance       | Credit card    | Life insurance   |   744.2  |       1.96 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-23 | Medical Expense | Credit card    | Consultation Fee |  1839.6  |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-24 | EMI             | Credit card    | Air conditioner  |   976.16 |       1.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-25 | Subscription    | Credit card    | Spotify          |   271.61 |       3.42 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-29 | EMI             | Credit card    | Mobile           |  1066.47 |       3.6  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-11 | Shopping        | Credit card    | Shopping expense |   741.44 |       2.31 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-19 | Electronics     | Credit card    | Mobile           |  1865.52 |       2.6  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-08 | Groceries       | Credit card    | Fruits           |  1491.5  |       3.4  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-15 | Insurance       | Credit card    | Health insurance |  1557.25 |       1.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-03 | Groceries       | Credit card    | Grains & Bread   |   920.19 |       1.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-03 | Shopping        | Credit card    | Shopping expense |    58.73 |       3.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-04 | Electronics     | Credit card    | Mobile           |   326.37 |       3.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-06 | Medical Expense | Credit card    | Medicine         |  1409.81 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-10 | Bills           | Credit card    | Mobile Recharge  |    98.69 |       3.34 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-12 | Transportation  | Credit card    | Flight           |   702.44 |       1.18 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | EMI             | Credit card    | Washing machine  |  1954.92 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | Shopping        | Credit card    | Shopping expense |   120.15 |       2.22 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-19 | Medical Expense | Credit card    | Medicine         |   692.3  |       1.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-20 | EMI             | Credit card    | Washing machine  |  1220.04 |       2.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-23 | Electronics     | Credit card    | Laptop           |   841.45 |       2.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-03 | Shopping        | Credit card    | Shopping expense |  1473.51 |       2.91 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-05 | Bills           | Credit card    | Mobile Recharge  |   362.32 |       2.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-06 | Shopping        | Credit card    | Shopping expense |  1393.6  |       2.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-29 | Bills           | Credit card    | Wifi bill        |   555.46 |       1.41 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-01 | Electronics     | Credit card    | Laptop           |   139.74 |       1.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-01 | Medical Expense | Credit card    | Consultation Fee |   569.72 |       3.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-26 | Medical Expense | Credit card    | Consultation Fee |   229.73 |       3.09 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-09 | Transportation  | Credit card    | Bus              |   880.07 |       2    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-14 | Electronics     | Credit card    | Laptop           |  1501.83 |       1.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-15 | Transportation  | Credit card    | Ola              |   109.17 |       2.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-22 | Groceries       | Credit card    | Fruits           |  1982.64 |       2.1  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-27 | Groceries       | Credit card    | Beverages        |   616.43 |       2.89 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-01 | Transportation  | Credit card    | Ola              |   709.45 |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-19 | EMI             | Credit card    | Mobile           |  1966.53 |       3.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-21 | Bills           | Credit card    | Gas bill         |   716.96 |       3.42 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-02 | EMI             | Credit card    | Washing machine  |   680.37 |       3.34 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-07 | Bills           | Credit card    | Wifi bill        |  1231.15 |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-12 | Bills           | Credit card    | Mobile Recharge  |   976.4  |       3.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-22 | Electronics     | Credit card    | Tablet           |  1880.6  |       3.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-24 | Transportation  | Credit card    | Bus              |  1075.64 |       3.23 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-25 | Subscription    | Credit card    | Spotify          |  1280.86 |       1.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-04 | Transportation  | Credit card    | Ola              |  1182.05 |       3.61 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-07 | Shopping        | Credit card    | Shopping expense |  1206.14 |       1.96 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-11 | Bills           | Credit card    | Wifi bill        |   180.41 |       1.51 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-19 | Insurance       | Credit card    | Auto insurance   |  1254.81 |       3.12 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-22 | Insurance       | Credit card    | Life insurance   |   744.2  |       1.96 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-23 | Medical Expense | Credit card    | Consultation Fee |  1839.6  |       2.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-24 | EMI             | Credit card    | Air conditioner  |   976.16 |       1.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-25 | Subscription    | Credit card    | Spotify          |   271.61 |       3.42 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-29 | EMI             | Credit card    | Mobile           |  1066.47 |       3.6  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-11 | Shopping        | Credit card    | Shopping expense |   741.44 |       2.31 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-19 | Electronics     | Credit card    | Mobile           |  1865.52 |       2.6  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-08 | Groceries       | Credit card    | Fruits           |  1491.5  |       3.4  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-15 | Insurance       | Credit card    | Health insurance |  1557.25 |       1.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-03 | Groceries       | Credit card    | Grains & Bread   |   920.19 |       1.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-03 | Shopping        | Credit card    | Shopping expense |    58.73 |       3.54 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-04 | Electronics     | Credit card    | Mobile           |   326.37 |       3.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-06 | Medical Expense | Credit card    | Medicine         |  1409.81 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-10 | Bills           | Credit card    | Mobile Recharge  |    98.69 |       3.34 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-12 | Transportation  | Credit card    | Flight           |   702.44 |       1.18 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | EMI             | Credit card    | Washing machine  |  1954.92 |       2.7  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-24 | Shopping        | Credit card    | Shopping expense |   120.15 |       2.22 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-19 | Medical Expense | Credit card    | Medicine         |   692.3  |       1.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-20 | EMI             | Credit card    | Washing machine  |  1220.04 |       2.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-23 | Electronics     | Credit card    | Laptop           |   841.45 |       2.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-03 | Shopping        | Credit card    | Shopping expense |  1473.51 |       2.91 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-05 | Bills           | Credit card    | Mobile Recharge  |   362.32 |       2.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-06 | Shopping        | Credit card    | Shopping expense |  1393.6  |       2.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-29 | Bills           | Credit card    | Wifi bill        |   555.46 |       1.41 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-01 | Electronics     | Credit card    | Laptop           |   139.74 |       1.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-01 | Medical Expense | Credit card    | Consultation Fee |   569.72 |       3.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-26 | Medical Expense | Credit card    | Consultation Fee |   229.73 |       3.09 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-06 | Insurance       | Credit card    | Life insurance   |  1124.8  |       2.28 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-16 | Insurance       | Credit card    | Auto insurance   |   501.57 |       1.56 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-19 | Electronics     | Credit card    | Mobile           |    58.33 |       1.47 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-27 | Bills           | Credit card    | Gas bill         |   461.12 |       3.56 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-30 | Subscription    | Credit card    | Netflix          |  1263.15 |       2.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-15 | Insurance       | Credit card    | Health insurance |  1289.95 |       2.83 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-19 | Groceries       | Credit card    | Grains & Bread   |  1520.8  |       2.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-20 | Groceries       | Credit card    | Fruits           |   797.29 |       2.4  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-03 | EMI             | Credit card    | Washing machine  |   315.63 |       3.05 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-15 | Electronics     | Credit card    | Laptop           |  1535.09 |       2.46 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-29 | Groceries       | Credit card    | Fruits           |  1915.91 |       2.61 |
# ...
# | 2024-12-20 | Subscription    | Credit card    | Spotify          |   531.12 |       2.44 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-02 | Insurance       | Credit card    | Auto insurance   |   487.26 |       1.98 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-21 | Shopping        | Credit card    | Shopping expense |   929.82 |       2.06 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-26 | Shopping        | Credit card    | Shopping expense |   123.11 |       2.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-26 | Groceries       | Credit card    | Fruits           |   952.55 |       1.76 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-28 | Subscription    | Credit card    | Netflix          |   121.49 |       1.37 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-03 | Insurance       | Credit card    | Auto insurance   |   366.19 |       1.07 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-11 | Subscription    | Credit card    | Netflix          |   282.71 |       2.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-11 | Medical Expense | Credit card    | Consultation Fee |   453.26 |       2.46 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-21 | Electronics     | Credit card    | Laptop           |   610.49 |       2.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-01 | Subscription    | Credit card    | Zomato           |   411.62 |       1.35 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-03 | Subscription    | Credit card    | Zomato           |   691.04 |       2.43 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-05 | Transportation  | Credit card    | Ola              |   219.19 |       2.17 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-13 | Groceries       | Credit card    | Diary & eggs     |   415.12 |       3.48 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-26 | Bills           | Credit card    | Wifi bill        |   764.61 |       1.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-30 | Groceries       | Credit card    | Vegetables       |   500.03 |       1.55 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-14 | Subscription    | Credit card    | Spotify          |   497.39 |       2.24 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-20 | Subscription    | Credit card    | Netflix          |   333.31 |       3.09 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-28 | Insurance       | Credit card    | Life insurance   |   989.1  |       2.55 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-03 | Insurance       | Credit card    | Auto insurance   |   834.26 |       3.49 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-09 | Medical Expense | Credit card    | Consultation Fee |   582.82 |       3.86 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-21 | Electronics     | Credit card    | Mobile           |   455.72 |       3.95 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-02 | Insurance       | Credit card    | Auto insurance   |   270.38 |       2.97 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-09 | Groceries       | Credit card    | Beverages        |   976.32 |       3.35 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-10 | Medical Expense | Credit card    | Medicine         |   875.58 |       1.27 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-14 | Groceries       | Credit card    | Diary & eggs     |   781.55 |       3.47 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-16 | Medical Expense | Credit card    | Consultation Fee |   230.74 |       2.36 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-12 | Shopping        | Credit card    | Shopping expense |   380    |       2.71 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-14 | Transportation  | Credit card    | Flight           |   718.47 |       1.86 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-26 | EMI             | Credit card    | Mobile           |   599.52 |       2.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-14 | Shopping        | Credit card    | Shopping expense |   475.27 |       3.88 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-05 | Transportation  | Credit card    | Flight           |   247.06 |       3.11 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-08 | Subscription    | Credit card    | Amazon Prime     |   634.06 |       3.42 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-09 | Medical Expense | Credit card    | Medicine         |   774.56 |       2.66 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-09-21 | Transportation  | Credit card    | Flight           |   148.97 |       3.61 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-08 | Groceries       | Credit card    | Fruits           |   562.3  |       1.21 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-12 | Transportation  | Credit card    | Bus              |    66.27 |       1.75 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-25 | Transportation  | Credit card    | Flight           |   124.37 |       3.89 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-25 | Electronics     | Credit card    | Tablet           |   197.25 |       2.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-09 | Groceries       | Credit card    | Vegetables       |   778.92 |       2.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-14 | Subscription    | Credit card    | Zomato           |   372.42 |       1.79 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-01 | Insurance       | Credit card    | Health insurance |   161.45 |       1.25 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-09 | Transportation  | Credit card    | Ola              |   171.43 |       1.97 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-10 | Shopping        | Credit card    | Shopping expense |   451.96 |       1.73 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-20 | Medical Expense | Credit card    | Consultation Fee |   482.96 |       3.73 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-22 | Shopping        | Credit card    | Shopping expense |   336.82 |       1.74 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-01-24 | Insurance       | Credit card    | Health insurance |   359.57 |       3.08 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-02-16 | Groceries       | Credit card    | Grains & Bread   |   355.83 |       2.89 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-06 | Insurance       | Credit card    | Health insurance |   488.12 |       2.43 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-22 | Medical Expense | Credit card    | Consultation Fee |   111.51 |       2.61 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-03-29 | Shopping        | Credit card    | Shopping expense |   845.18 |       1.32 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-03 | Transportation  | Credit card    | Ola              |   972.25 |       3.59 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-04 | Shopping        | Credit card    | Shopping expense |   361.06 |       2.63 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-04 | Electronics     | Credit card    | Mobile           |   795.63 |       3.45 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-10 | Insurance       | Credit card    | Auto insurance   |   750.28 |       2.13 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-12 | Shopping        | Credit card    | Shopping expense |   188.36 |       1.76 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-04-18 | Bills           | Credit card    | Gas bill         |   828.8  |       3.58 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-06 | Shopping        | Credit card    | Shopping expense |   487.3  |       1.03 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-21 | Transportation  | Credit card    | Flight           |   133.02 |       1.72 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-26 | Shopping        | Credit card    | Shopping expense |   484.16 |       2.73 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-27 | Groceries       | Credit card    | Spices           |   403.17 |       3.9  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-05-28 | Transportation  | Credit card    | Bus              |   475.72 |       3.18 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-02 | Medical Expense | Credit card    | Medicine         |   489.77 |       2.98 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-05 | Insurance       | Credit card    | Health insurance |   711.49 |       1.85 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-18 | Insurance       | Credit card    | Auto insurance   |   171.52 |       2.04 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-06-19 | Medical Expense | Credit card    | Consultation Fee |   975.35 |       1.94 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-04 | Shopping        | Credit card    | Shopping expense |   737.52 |       2.43 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-14 | Groceries       | Credit card    | Fruits           |   394.16 |       2.95 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-26 | Shopping        | Credit card    | Shopping expense |   199.22 |       3.57 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-07-27 | Electronics     | Credit card    | Mobile           |   263.93 |       3.92 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-02 | Shopping        | Credit card    | Shopping expense |   857.56 |       3.53 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-06 | Subscription    | Credit card    | Zomato           |   967.29 |       2.73 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-16 | Transportation  | Credit card    | Bus              |   980.39 |       1.84 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-08-20 | Insurance       | Credit card    | Health insurance |   268.65 |       2.15 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-06 | Shopping        | Credit card    | Shopping expense |   833.82 |       3.2  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-15 | Electronics     | Credit card    | Laptop           |   562.11 |       3.36 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-16 | Transportation  | Credit card    | Train            |   165.6  |       3.52 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-21 | Electronics     | Credit card    | Mobile           |   904.58 |       2.52 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-10-21 | Transportation  | Credit card    | Flight           |   748.97 |       1.99 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-06 | Medical Expense | Credit card    | Medicine         |   601.59 |       1.94 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-07 | Shopping        | Credit card    | Shopping expense |   128.59 |       2    |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-11-12 | Bills           | Credit card    | Gas bill         |   885.69 |       2.4  |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-07 | Insurance       | Credit card    | Auto insurance   |   703.21 |       3.93 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-08 | Transportation  | Credit card    | Train            |   730.07 |       3.55 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-11 | EMI             | Credit card    | Car              |   734.15 |       3.81 |
# +------------+-----------------+----------------+------------------+----------+------------+
# | 2024-12-14 | Shopping        | Credit card    | Shopping expense |   884.45 |       2.93 |
# +------------+-----------------+----------------+------------------+----------+------------+

# %%
#Query 18: Total Amount Spent on Medical Expenses

query18 = """
SELECT SUM(amount) AS total_medical_spending
FROM expenses_data
WHERE LOWER(category) = 'medical expense';
"""
cursor.execute(query18)
result18 = cursor.fetchall()

# Convert query result to Pandas DataFrame
df_total_medical_bill = pd.DataFrame(result18, columns=['Total medical bill'])

# Display the table
print(df_total_medical_bill)
# Out:
#    Total medical bill
# 0          2047319.99
